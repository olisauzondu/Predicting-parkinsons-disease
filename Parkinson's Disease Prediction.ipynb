# %% [markdown]
# ## Parkinson's Disease Prediction
# This project is about creating a prediction model for parkinson's disease.
#
# ### Objective
# To learn how to apply feature engineering to build a machine learning model for prediction purposes.
#
# ### Question to answer
# How can we determine teh risk of having parkinson's disease based on certain attributes so as to tailor the right level of attention to the patient?
#
# ### Solution Workflow
#  - Identify question
#  - Import libraries
#  - Get and clean data
#  - Exploratory data analysis
#  - Feature selection
#  - Apply techniques
#  - Share insights

# %% [markdown]
# #### Import libraries

# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import os, sys
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score
import sklearn.metrics as metrics
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
import joblib
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Get and clean data

# %%
parkdf = pd.read_csv('parkinsons.csv')
parkdf.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
#display all columns
pd.set_option('display.max_columns',None)
parkdf.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374
# 1           0.00008   0.00465   0.00696     0.01394       0.06134
# 2           0.00009   0.00544   0.00781     0.01633       0.05233
# 3           0.00009   0.00502   0.00698     0.01505       0.05492
# 4           0.00011   0.00655   0.00908     0.01966       0.06425
#
#    MDVP:Shimmer(dB)  Shimmer:APQ3  Shimmer:APQ5  MDVP:APQ  Shimmer:DDA  \
# ...

# %%
parkdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
# ...

# %%
parkdf.shape
# Out:
# (195, 24)

# %%
#describe the data for some statistical value
parkdf.describe().T
# Out:
#                   count        mean        std         min         25%  \
# MDVP:Fo(Hz)       195.0  154.228641  41.390065   88.333000  117.572000
# MDVP:Fhi(Hz)      195.0  197.104918  91.491548  102.145000  134.862500
# MDVP:Flo(Hz)      195.0  116.324631  43.521413   65.476000   84.291000
# MDVP:Jitter(%)    195.0    0.006220   0.004848    0.001680    0.003460
# MDVP:Jitter(Abs)  195.0    0.000044   0.000035    0.000007    0.000020
# MDVP:RAP          195.0    0.003306   0.002968    0.000680    0.001660
# MDVP:PPQ          195.0    0.003446   0.002759    0.000920    0.001860
# Jitter:DDP        195.0    0.009920   0.008903    0.002040    0.004985
# MDVP:Shimmer      195.0    0.029709   0.018857    0.009540    0.016505
# MDVP:Shimmer(dB)  195.0    0.282251   0.194877    0.085000    0.148500
# Shimmer:APQ3      195.0    0.015664   0.010153    0.004550    0.008245
# Shimmer:APQ5      195.0    0.017878   0.012024    0.005700    0.009580
# ...

# %%
#plot correlation matrix
corr = round(parkdf.corr(),2)
plt.figure(figsize=(16,10))
sns.heatmap(corr,vmin=-1,vmax=1,center=0,annot=True,cmap=sns.color_palette("coolwarm", as_cmap=True))
# Out:
# <AxesSubplot:>

# %% [markdown]
# The column 'Status" indicates how many people suffer from parkinsons

# %%
ax=sns.countplot(x='status',data=parkdf)
for p in ax.patches:
   ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.3, p.get_height()+0.01))

# %% [markdown]
# There is about 150 patients with parkinsons didease and about 50 without in this data

# %% [markdown]
# #### Feature selection

# %%
#rearrange columns for feature selection
parkdf.columns
# Out:
# Index(['name', 'MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(%)',
#        'MDVP:Jitter(Abs)', 'MDVP:RAP', 'MDVP:PPQ', 'Jitter:DDP',
#        'MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5',
#        'MDVP:APQ', 'Shimmer:DDA', 'NHR', 'HNR', 'status', 'RPDE', 'DFA',
#        'spread1', 'spread2', 'D2', 'PPE'],
#       dtype='object')

# %%
parkdf = parkdf[['name', 'MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(%)',
       'MDVP:Jitter(Abs)', 'MDVP:RAP', 'MDVP:PPQ', 'Jitter:DDP',
       'MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5',
       'MDVP:APQ', 'Shimmer:DDA', 'NHR', 'HNR', 'RPDE', 'DFA',
       'spread1', 'spread2', 'D2', 'PPE', 'status']]

#create copy of data
df = parkdf.copy()

#convert categorical columns to numeric (only one object type column - name)
num = LabelEncoder()
df['name'] = num.fit_transform(df['name'])
df.head()
# Out:
#    name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0     0      119.992       157.302        74.997         0.00784
# 1     1      122.400       148.650       113.819         0.00968
# 2     2      116.682       131.111       111.555         0.01050
# 3     3      116.676       137.871       111.366         0.00997
# 4     4      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374
# 1           0.00008   0.00465   0.00696     0.01394       0.06134
# 2           0.00009   0.00544   0.00781     0.01633       0.05233
# 3           0.00009   0.00502   0.00698     0.01505       0.05492
# 4           0.00011   0.00655   0.00908     0.01966       0.06425
#
#    MDVP:Shimmer(dB)  Shimmer:APQ3  Shimmer:APQ5  MDVP:APQ  Shimmer:DDA  \
# 0             0.426       0.02182       0.03130   0.02971      0.06545
# ...

# %%
X = df.iloc[:,0:14] #features
Y = df.iloc[:,-1] #target variable. parkinsons or not

best_features = SelectKBest(score_func=chi2,k=5) #function that select top 5 features
fit = best_features.fit(X,Y)
# creat dataframe for features and score of features
parkinson_scores = pd.DataFrame(fit.scores_)
parkinson_columns = pd.DataFrame(X.columns)

# %%
#create a dataframe that combine all features and their scores
features_scores = pd.concat([parkinson_columns,parkinson_scores],axis=1)
features_scores.columns = ['Feature','Score']
features_scores.sort_values(by='Score')
# Out:
#              Feature       Score
# 5   MDVP:Jitter(Abs)    0.000614
# 7           MDVP:PPQ    0.035713
# 6           MDVP:RAP    0.036749
# 4     MDVP:Jitter(%)    0.056742
# 8         Jitter:DDP    0.110222
# 11      Shimmer:APQ3    0.154276
# 12      Shimmer:APQ5    0.193435
# 13          MDVP:APQ    0.307076
# 9       MDVP:Shimmer    0.313475
# 10  MDVP:Shimmer(dB)    3.210348
# 0               name  178.712392
# 2       MDVP:Fhi(Hz)  227.402656
# 1        MDVP:Fo(Hz)  316.985398
# 3       MDVP:Flo(Hz)  456.626628

# %% [markdown]
# It seems the top features are:
#  - MDVP:Flo(Hz)
#  - MDVP:Fo(Hz)
#  - MDVP:Fhi(Hz)
#
# The others don't have a high score as those three

# %% [markdown]
# #### Apply techniques
# Build model

# %%
x = parkdf[['MDVP:Flo(Hz)','MDVP:Fo(Hz)','MDVP:Fhi(Hz)']]
y = parkdf['status']

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=7)
model = XGBClassifier() #xgbclassifier used for categorical target (classification problem) 
model.fit(x_train,y_train)
# Out:
# [11:25:02] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=4,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %% [markdown]
# Evaluate model

# %%
y_pred = model.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.8979591836734694

# %% [markdown]
# The model has an **89.8% accuracy** in prediction

# %%
#define metrics
y_pred_prob = model.predict_proba(x_test) [:,1]

#calulate true and false positive rates
false_positive_rate,true_positive_rate,_ = metrics.roc_curve(y_test,y_pred_prob)

#calculate area under roc curve
auc = metrics.roc_auc_score(y_test,y_pred_prob)

#Create ROC curve
plt.plot(false_positive_rate, true_positive_rate,label="AUC="+str(auc))
plt.title('ROC Curve')
plt.ylabel('True Positive Rate')
plt.xlabel('false Positive Rate')
plt.legend(loc='lower right')

# %% [markdown]
# With the **area under curve of about 0.87**, means the model is performing well enough.
#
# Save model for later use

# %%
import pickle
park_model = 'park_model.sav'
pickle.dump(model,open(park_model, 'wb'))

# %%
#to make predictions, input format to code: (MDVP:Flo(Hz),MDVP:Fo(Hz),MDVP:Fhi(Hz))
x_pred = np.array([[150,174,118]])
#load model for use using
loaded_model = pickle.load(open(park_model,'rb'))
result=loaded_model.predict(x_pred)
print(result)
# Out:
# [0]

# %% [markdown]
# ### Insights
# **The parkinson's detection model was created with 3 features as input** for its classificaiton determination.
#
# **The model has an 89.8% accuracy** in classifying parkinson's patients. Thus, this model can be used to help doctors implement what level of attention to give to patients
